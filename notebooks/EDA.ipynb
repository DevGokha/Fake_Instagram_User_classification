# %%
# 1. Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. Load Dataset
df = pd.read_csv('C:/Users/DEV/Downloads/Fake_Instagram_User_Classification/Fake_Instagram_User_Classification/data/fake_instagram_users_synthetic.csv')

df.head()
# Out:
#       username  followers  following  posts  bio_length  profile_pic  \
# 0  fake_user_1         67        602      4           7            0
# 1  fake_user_2         81        919     10          17            0
# 2  fake_user_3        226        630      0           2            0
# 3  fake_user_4        129       2569      9           0            0
# 4  fake_user_5        289       2218      3          14            1
#
#    external_url  is_fake
# 0             1        1
# 1             1        1
# 2             1        1
# 3             1        1
# 4             1        1

# %%
# 3. Basic Info
print("Shape:", df.shape)
df.info()
# Out:
# Shape: (100, 8)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   username      100 non-null    object
#  1   followers     100 non-null    int64
#  2   following     100 non-null    int64
#  3   posts         100 non-null    int64
#  4   bio_length    100 non-null    int64
#  5   profile_pic   100 non-null    int64
#  6   external_url  100 non-null    int64
#  7   is_fake       100 non-null    int64
# dtypes: int64(7), object(1)
# memory usage: 6.4+ KB

# %%
# 4. Summary Statistics
df.describe()
# Out:
#          followers    following       posts  bio_length  profile_pic  \
# count   100.000000   100.000000  100.000000  100.000000   100.000000
# mean   1346.620000   983.940000   80.970000   44.040000     0.700000
# std    1557.411714   922.066704   96.435403   39.030918     0.460566
# min      13.000000    54.000000    0.000000    0.000000     0.000000
# 25%     132.750000   226.000000    5.000000   10.000000     0.000000
# 50%     301.000000   510.500000   20.500000   25.000000     1.000000
# 75%    2544.750000  1593.750000  148.000000   78.750000     1.000000
# max    4894.000000  2984.000000  296.000000  120.000000     1.000000
#
#        external_url     is_fake
# count    100.000000  100.000000
# mean       0.750000    0.500000
# std        0.435194    0.502519
# min        0.000000    0.000000
# 25%        0.750000    0.000000
# 50%        1.000000    0.500000
# 75%        1.000000    1.000000
# max        1.000000    1.000000

# %%
# 5. Check for Null Values
df.isnull().sum()
# Out:
# username        0
# followers       0
# following       0
# posts           0
# bio_length      0
# profile_pic     0
# external_url    0
# is_fake         0
# dtype: int64

# %%
# 6. Class Distribution
sns.countplot(data=df, x='is_fake')  # Replace with actual target column name
plt.title("Real vs Fake User Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Select only numeric columns
numeric_df = df.select_dtypes(include='number')

# 2. Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# 8. Pairplot (Optional, slow on big data)
# sns.pairplot(df, hue='is_fake')

# 9. Feature Distributions
num_cols = df.select_dtypes(include=np.number).columns.tolist()
df[num_cols].hist(figsize=(12, 8))
plt.tight_layout()
plt.show()
